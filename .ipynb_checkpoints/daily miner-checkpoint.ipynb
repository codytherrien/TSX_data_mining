# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
import csv
import os
import datetime
import time
import random
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
pd.options.display.float_format = '{:.0f}'.format
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/87.0.4280.88/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\c_the\.wdm\drivers\chromedriver\win32\87.0.4280.88]

# %%
def cap_finder(cap_string):
    cap = float(cap_string[0:-1].replace(',',''))
    if cap_string[-1] == 'B':
        cap = cap*10**9
    elif cap_string[-1] == 'M':
        cap = cap*10**6
    elif cap_string[-1] == 'T':
        cap = cap*10**12
    return cap

def close_date_func(close_day):
    today = datetime.date.today()
    while close_day != today.day:
        today = today - datetime.timedelta(days = 1)
    return today

# %%
def open_link(symbol):
    is_link = 'https://ca.finance.yahoo.com/quote/'+ symbol +'.TO/key-statistics?p=' + symbol + '.TO&.tsrc=fin-srch'
    
    #driver = webdriver.Chrome()
    driver.get(is_link)
    time.sleep(random.uniform(0.5, 3))
    html = driver.execute_script('return document.body.innerHTML;')
    soup = BeautifulSoup(html,'lxml')
    return soup

# %%
def collect_data(symbol, soup):
    close_price = [entry.text for entry in soup.find_all('span', {'class':'Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)'})]
    close_price = float(close_price[0].replace(',',''))
    close_price
    
    metrics = [entry.text for entry in soup.find_all('td', {'class':'Fw(500) Ta(end) Pstart(10px) Miw(60px)'})]
    if metrics[0] == 'N/A':
        cap = 'N/A'
    else:
        cap = cap_finder(metrics[0])
    if metrics[2] == 'N/A':
        P_to_E = metrics[2]
    else:
        P_to_E = float(metrics[2].replace(',',''))
    if metrics[4] == 'N/A':
        PEG = metrics[4]
    else:
        PEG = float(metrics[4].replace(',',''))
    if metrics[6] == 'N/A':
        P_to_B = metrics[6]
    else:
        P_to_B = float(metrics[6].replace(',',''))
    if metrics[28] == 'N/A':
        Dividend = metrics[28]
    else:
        Dividend = cap_finder(metrics[28])/100
    if metrics[32] == 'N/A':
        Payout_ratio = metrics[32]
    else:
        Payout_ratio = cap_finder(metrics[32])/100
    
    
    full_name = [entry.text for entry in soup.find_all('h1', {'class':'D(ib) Fz(18px)'})]
    full_name = full_name[0]
    name = full_name.split('(')[0].strip()
    name = name.replace(',','')
    
    #symbol = full_name.split('(')[1]
    #symbol = symbol.split('.')[0]
    
    if P_to_E == 'N/A' or P_to_B == 'N/A':
        value = 'N/A'
    elif Dividend == 'N/A':
        value = P_to_E*P_to_B
    else:
        value = P_to_E*P_to_B/(1+Dividend)
    
    
    date_info = [entry.text for entry in soup.find_all('span', {'data-reactid':'35'})]
    date_info = date_info[0].split(':')[1].strip()
    date_info = date_info.split(' ')
    try:
        close_day = int(date_info[1])
        close_date = close_date_func(close_day)
    except:
        close_date = datetime.date.today()
    
    return [name, symbol, close_date.year, close_date.month, close_date.day, close_price,\
            cap, P_to_E, PEG, P_to_B, Dividend, Payout_ratio, value]

# %%
def store_data(symbol, important_metrics):
    if os.path.isfile('Data/' + symbol + '-TO.csv'):
        with open('Data/' + symbol +'-TO.csv', mode = 'r', newline = '') as curr_file:
            csv_reader = csv.reader(curr_file, delimiter = ',')
            for line in csv_reader:
                if line[7] == 'Industry':
                    continue
                else:
                    sector = line[6]
                    industry = line[7]
                    break
            curr_file.close()
            
        with open('Data/' + symbol +'-TO.csv', mode = 'a', newline = '') as curr_file:
            curr_writer = csv.writer(curr_file, delimiter = ',')
            curr_writer.writerow(important_metrics[0:6] + [sector, industry] + important_metrics[6:])
            curr_file.close()
            
    else:
        is_link = 'https://ca.finance.yahoo.com/quote/' + symbol + '.TO/profile?p=' + symbol + '.TO'
        driver.get(is_link)
        html = driver.execute_script('return document.body.innerHTML;')
        soup = BeautifulSoup(html,'lxml') 
        
        industrys = [entry.text for entry in soup.find_all('span', {'class':'Fw(600)'})]
        try:
            industry = industrys[-2]
            if len(industry) == 0:
                industry = 'N/A'
        except:
            industry = 'N/A'
        try:
            sector = industrys[0]
            if len(sector) == 0:
                sector = 'N/A'
        except:
            sector = 'N/A'
        
        with open('Data/' + symbol + '-TO.csv', mode = 'w', newline = '') as curr_file:
            curr_writer = csv.writer(curr_file, delimiter = ',')
            curr_writer.writerow(['Company Name', 'Symbol', 'Year', 'Month', 'Day', 'Close Price', 'Sector',\
                                  'Industry', 'Market Cap', 'Price to Earnings', 'PEG',\
                                  'Price to Book', 'Dividend', 'Payout Ratio', 'Value Metric'])
            curr_writer.writerow(important_metrics[0:6] + [sector, industry] + important_metrics[6:])
            curr_file.close()
    
    return important_metrics[0:6] + [sector, industry] + important_metrics[6:]

# %%
def open_list():
    symbol_list = []
    with open('symbol list.csv', mode = 'r', newline = '') as f:
        csv_reader = csv.reader(f, delimiter = ',')
        for line in f:
            symbol_list.append(line.strip())
        f.close()

    return symbol_list

# %%
def mine_market():
    start_time = datetime.datetime.now()
    symbol_list = open_list()
    todays_list = []
    symbol_list = [x for x in symbol_list if x not in todays_list]
    while len(symbol_list) > 0:
        try:
            random.shuffle(symbol_list)
            counter = random.randint(0,30)
            for symbol in symbol_list:
                counter += 1
                if counter == 100:
                    counter = random.randint(0,30)
                    time.sleep(3*counter)
                print(symbol + ', ', end = '')
                soup = open_link(symbol)
                try: 
                    important_metrics = collect_data(symbol, soup)
                except:
                    time.sleep(30)
                    soup = open_link(symbol)
                    importand_metrics = collect_data(symbol, soup)
                important_metrics = store_data(symbol, important_metrics)
                todays_list.append(symbol)
        finally:
            symbol_list = [x for x in symbol_list if x not in todays_list]
    print()
    print('Data Stored!!')
    print('Runtime: ' + str(datetime.datetime.now() - start_time))

# %%
def mining_correction(symbol_list):
    start_time = datetime.datetime.now()
    todays_list = []
    symbol_list = [x for x in symbol_list if x not in todays_list]
    
    for symbol in symbol_list:
        f = open('Data/' + symbol +'-TO.csv', "r+")
        lines = f.readlines()
        lines.pop()
        f = open('Data/' + symbol +'-TO.csv', "w+")
        f.writelines(lines)

    while len(symbol_list) > 0:
        try:
            random.shuffle(symbol_list)
            counter = random.randint(0,30)
            for symbol in symbol_list:
                counter += 1
                if counter == 100:
                    counter = random.randint(0,30)
                    time.sleep(3*counter)
                print(symbol + ', ', end = '')
                soup = open_link(symbol)
                try: 
                    important_metrics = collect_data(symbol, soup)
                except:
                    time.sleep(30)
                    soup = open_link(symbol)
                    importand_metrics = collect_data(symbol, soup)
                important_metrics = store_data(symbol, important_metrics)
                todays_list.append(symbol)
        finally:
            symbol_list = [x for x in symbol_list if x not in todays_list]
    print()
    print('Data Updated!!')
    print('Runtime: ' + str(datetime.datetime.now() - start_time))

# %%
#time.sleep(5000)
mine_market()
# Out:
# CTC, CIQ-UN, MAG, ENI-UN, DN, QETH-U, AIM, SU, EVT, MAXR, RUS, PAAS, COG, EDV, GMX, RY, PHYS, ENS, ETG, MDF, SJ, ZZZ, CWX, MDC-UN, RBN-UN, CCA, NWC, RIB-UN, OR, XAU, MEQ, QSR, VCM, CFX, CPG, SAU, ABX, MRD, MRC, AJX, SBC, SNC, GDV, AIF, CSW-A, PRN, GRT-UN, WM, NEXT, LAS-A, TBL, FFH-U, REI-UN, LGD, ETX, KOR, SGR-UN, CNQ, PVG, BYL, TC, MRT-UN, QBR-B, IFC, ME, LUG, GH, GATO, FAF, LAM, AHC, NSR, OLA, CU, TECK-A, CM, GSC, WSP, TRQ, AVL, LXR, PLC, ITH, DCM, CJ, FRU-R, ORA, FFN, BUI, PIF, HUT, IGM, IN, TOT, LSPD, JWEL, CGX, SEC, AYA, WCN, SRV-UN, MG, NWH-UN, NVCN, DOL, ECN, BNG, DR, AGI, FAR, NCM, MMX, ADW-B, CS, OGC, TKO, XTD, BNS, SPPP, NFI, IBG, BNE, SLF, SBB, MGA, CRH, FSY, TCT-UN, NUAG, APR-UN, DXT, BIR, ACB, DNG, HPS-A, CEU, VFF, FIH-U, TRL, ITP, FSZ, NDM, WIR-U, AFN, POW, TGOD, LCS, PNC-B, BIPC, WEF, TVK, U, CSU, YGR, FRU, CJT, SAM, CEF, DGS, NEO, CIX, RDL, CWL, BEK-B, BNK, SHLE, ASP, TVA-B, CRWN, SVM, FTU, HZM, NSR-WT, GDL, XCT, VLNS, KMP-UN, UFS, CDV, SOT-UN, GCM, SIL, XTC, ECO, EFL, III, AUP, BLU, WRN, EDT, SCL, ISV, TF, TGZ, TPZ, ALB, TML, CP, K, AOT, FTS, QTRH, EMA, YCM, FXC, ATP, ONEX, LGO, FURY, JAG, MARI, PPL, TBP, CLIQ, SFD, LIF, BHC, PRMW, TBP-WT, VB, STEP, PRQ, ERE-UN, CR, LFE, BDT, GVC, NEPT, SXP, CFW-WT, ERD, NG, BLB-UN, OPS, MDNA, PPR, CUF-UN, RAY-A, FM, KL, HRX, ORL, NHF-UN, MTL, TA, AZZ, GCG-A, FEC, AQN, ENGH, STN, ADW-A, ARX, MBN, HCG, VMD, LN, SPG, GURU, SII, BPY-UN, BRE, DIV, IAG, GDI, SHOP, ACO-Y, TCL-A, DBO, SMU-UN, CPH, DF, HMM-A, ACQ, ALS, CRT-UN, CU-X, AC, MCB, SJR-B, HLF, PHO, USA, BAM-A, AAB, GDC, NIF-UN, RS, CGO, KEL, HR-UN, IFA, CHP-UN, TNX, FTG, EQB, BR, HEXO, STLC, POU, AKT-A, AP-UN, JFS-UN, ONC, ARE, ROXG, GOOS, MMP-UN, IFP, LNR, S, URB-A, DIR-UN, KRR, LBS, WBR, CAE, MAL, WCP, BBD-A, NEXA, BRY, WEED, VGZ, CFF, FC, TGO, PIPE-WT, IVQ-U, YRI, WILD, SSL, APLI, PBH, PBY-UN, OSK, FCU, PSD, HAI, DOO, TMR, MBA, VET, UEX, INC-UN, AEM, INE, BUA-UN, SGQ, PEA, TEV, ZENA, APHA, TV, NCU, TRIL, ACO-X, LUC, UNI, DCBO, CPI, FR, HOM-U, UNS, APY, ASM, RBA, CMMC, KEY, GCL, FTN, ELD, MR-UN, TXP, QBTC, TOU, YRB, TFII, SIS, D-UN, PHYS-U, MSV, EOX, CWEB-WR, TRP, OMI, SZLS-WS, FTT, PMT, BEPC, XMF-A, SBI, NCF, TZS, VNP, GEC-UN, NOA, CERV, ELEF, CSH-UN, ROOT, EFR, PNE, TWM, KPT, RAY-B, CSM, CVG, RTG, PME, ORV, PEY, BK, PGI-UN, DRX, RPI-UN, OLY, TV-WT, AMM, SZLS, DPM, PNP, PMN, ATZ, GCG, OVV, AT, XAM, GDG-UN, OBE, MIN, TCN, TD, TSU, ANX, HBM, TXG, MRG-UN, ELR, RCG, CMG, SLR, JOY, APS, TWC, NGD, BSO-UN, CIGI, HDI, WFS, PG, SSF-UN, MFI, IVQ, T, SIA, WELL, WCM-A, ALYA, AOI, OREA, TLG, CG, CNT, WJX, CEE, PRV-UN, ATD-A, MID-UN, AEG, MUX, PNC-A, EGLX, BCI, BSX, TSL, PZA, QEC, BTCG-U, IPO, CRDL, ALC, WPK, KRR-WT, SAP, HGI-UN, CXB, NTR, FIRE, GLG, PYR, EDR, HSE, NPK, MBX, CFP, WN, BLDP, KLS, GOLD, CHE-UN, BOS, LNF, BU, HWO, BB, FRL-UN, AW-UN, PHX, GTMS, REAL, TIH, TGOD-WR, WRG, EQX, LABS, BC-U, CLS, FNV, SPB, ESI, PSLV-U, TH, ADN, HRR-UN, PTS, TPX-B, WRX, CVE, PATH, DII-A, URE, PTI-UN, CTX, PMB-UN, MXG, ICE, GLXY, MRV, QSP-UN, FFH, MPVD, GWO, NA, CET, CWB, LGT-A, FF, VGCX, FVL, GENM, DND, EXN, UTE-UN, CNU, OGD, IMP, WFC, BPF-UN, RNW, MOZ, CHR, PFB, RCI-A, GIB-A, IVN, AII, SRU-UN, PSI, AGF-B, CGG, WPRT, JE, FRX, SXI, AKT-B, HOT-UN, MX, CTF-UN, BBU-UN, IIP-UN, BGI-UN, KNT, GGD, PXT, GLO, TRZ, CCO, ESM, MIC, PIPE, LUN, CAR-UN, UNC, GIL, GC, DII-B, EIF, BTCG-UN, OSP, CDD-UN, OTEX, HOM-UN, MPC, CF, MDS-UN, DRT, GAU, TCL-B, AEZS, FN, MRE, SWP, RIV, QBTC-U, CXI, GSV, MOGO, IMO, FRII, INQ, BYD, GGA, HFPC-U, TLO, HWX, CIA, IMG, CYB, MAV, ASND, CKI, VIVO, SMT, BIP-UN, NHK, MPCT-UN, POM, PRM, AND, KRN, CJR-B, MTY, PRU, TCS, ALA, ITE, ATH, USF-UN, AYM, X, RFP, BNAU, DRM, SPPP-U, GXE, PD, LGT-B, SIH-UN, VLE, KEI, TOG, TRI, MBCN, CEF-U, DNT, GSY, SWH, TSK, DIAM, FCR-UN, HRT, FVI, WPM, WTE, CGY, WDO, CRON, MAX, QBR-A, CCL-A, BCE, ERF, NVEI-U, KXS, NPI, FSV, RCO-UN, Y, MKP, AVCN, ATE, NXJ, SOY, MI-UN, FOOD, TNT-UN, PL, MRU, CUP-U, GFL, AH, SW, CDAY, ELF, STGO, GWR, TECK-B, DS, CGI, ET, GCT, EFN, RECP, MSI, HBL-UN, AR, AAV, ERO, GPR, PSK, SKE, INF-U ...
# Data Stored!!
# Runtime: 1:26:14.773104

# %%
symbol_list = open_list()
tsx_df = None
min_len = 16
max_len = 0
off_syms = []
for symbol in symbol_list:
    with open('Data/' + symbol +'-TO.csv', mode = 'r', newline = '') as curr_file:
        curr_data = curr_file.readlines()[-1]
        curr_file.close()
    curr_data = curr_data.strip().split(',')
    min_len = min(len(curr_data), min_len)
    max_len = max(len(curr_data), max_len)
    if len(curr_data) != 15:
        off_syms.append(symbol)
    if tsx_df is not None:
        tsx_df.loc[len(tsx_df)] = curr_data
        #tsx_df = tsx_df.append([curr_data])
    else:
        tsx_df = pd.DataFrame([curr_data], columns = ['Company Name', 'Symbol', 'Year',\
                                                        'Month', 'Day', 'Closing Price', 'Sector', 'Industry',\
                                                        'Market Cap', 'Price to Earnings', 'PEG',\
                                                        'Price to Book', 'Dividend', 'Payout Ratio', 'Value Metric'])
tsx_df.to_csv('tsx.csv', encoding = 'utf-8', index = False)
print('Data ready for analysis!!')
print(min_len)
print(max_len)
print(off_syms)
# Out:
# Data ready for analysis!!
# 15
# 15
# []

# %%
symbol_list = ['DIR-UN', 'VMD', 'BGI-UN', 'LN']
mining_correction(symbol_list)
# Out:
# VMD, DIR-UN, BGI-UN, LN,
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-41-7cb7e70ee428> in <module>
#       1 symbol_list = ['DIR-UN', 'VMD', 'BGI-UN', 'LN']
# ----> 2 mining_correction(symbol_list)
#
# <ipython-input-38-3441069c22e0> in mining_correction(symbol_list)
#      28                     soup = open_link(symbol)
#      29                     importand_metrics = collect_data(symbol, soup)
# ---> 30                 important_metrics = store_data(symbol, important_metrics)
#      31                 todays_list.append(symbol)
#      32         finally:
#
# <ipython-input-35-93ad50afc95a> in store_data(symbol, important_metrics)
#      14         with open('Data/' + symbol +'-TO.csv', mode = 'a', newline = '') as curr_file:
#      15             curr_writer = csv.writer(curr_file, delimiter = ',')
# ---> 16             curr_writer.writerow(important_metrics[0:6] + [sector, industry] + important_metrics[6:])
#      17             curr_file.close()
#      18
#
# UnboundLocalError: local variable 'sector' referenced before assignment

# %%
tsx_df.sort_values(by =['Value Metric'], ascending = True)
tsx_df.head(20)
# Out:
#                           Company Name  Symbol  Year Month Day Closing Price  \
# 0                 Lucara Diamond Corp.     LUC  2021     1   7          0.63
# 1                Enterprise Group Inc.       E  2021     1   7          0.22
# 2                   Urbana Corporation     URB  2021     1   6          2.93
# 3               Buhler Industries Inc.     BUI  2021     1   6           2.7
# 4          Gold Standard Ventures Corp     GSV  2021     1   7          0.93
# 5               Endeavour Silver Corp.     EDR  2021     1   7          6.82
# 6                          Opsens Inc.     OPS  2021     1   7          1.39
# 7                        M Split Corp.   XMF-A  2021     1   6          0.49
# 8              Chesswood Group Limited     CHW  2021     1   7          8.91
# 9              Life & Banc Split Corp.     LBS  2021     1   7           7.3
# 10    Precious Metals and Mining Trust  MMP-UN  2021     1   7          2.39
# 11  Sherritt International Corporation       S  2021     1   7          0.53
# 12                      Ur-Energy Inc.     URE  2021     1   7          1.08
# 13         Thomson Reuters Corporation     TRI  2021     1   7        102.26
# 14                    InPlay Oil Corp.     IPO  2021     1   7          0.26
# 15                   Aegis Brands Inc.     AEG  2021     1   7          0.93
# 16                        NorZinc Ltd.     NZC  2021     1   7         0.075
# 17                 Valeura Energy Inc.     VLE  2021     1   7          0.52
# 18                Parex Resources Inc.     PXT  2021     1   7         19.91
# 19               Petrus Resources Ltd.     PRQ  2021     1   7          0.27
#
#                 Sector                             Industry  \
# 0      Basic Materials       Other Precious Metals & Mining
# 1          Industrials           Engineering & Construction
# 2   Financial Services                     Asset Management
# 3          Industrials  Farm & Heavy Construction Machinery
# 4      Basic Materials                                 Gold
# 5      Basic Materials                               Silver
# 6           Healthcare       Medical Instruments & Supplies
# 7   Financial Services                     Asset Management
# 8   Financial Services                      Credit Services
# 9   Financial Services                     Asset Management
# 10  Financial Services                     Asset Management
# 11     Basic Materials     Other Industrial Metals & Mining
# 12              Energy                              Uranium
# 13         Industrials                  Consulting Services
# 14              Energy                        Oil & Gas E&P
# 15   Consumer Cyclical                          Restaurants
# 16     Basic Materials     Other Industrial Metals & Mining
# 17              Energy                        Oil & Gas E&P
# 18              Energy                        Oil & Gas E&P
# 19              Energy                        Oil & Gas E&P
#
#             Market Cap Price to Earnings    PEG Price to Book  \
# 0          250050000.0               N/A  10.46          1.27
# 1           10950000.0               N/A    N/A          0.29
# 2          162280000.0             56.35    N/A          0.59
# 3           67500000.0               N/A    N/A          0.83
# 4          293100000.0               N/A   -9.1          1.13
# 5   1070000000.0000001               N/A  -0.14          7.82
# 6          125490000.0               N/A    N/A          8.18
# 7            1120000.0               N/A    N/A           N/A
# 8          145100000.0               N/A    N/A          1.18
# 9          199260000.0               N/A    N/A          1.91
# 10          40970000.0               2.6    N/A          1.01
# 11         210560000.0               N/A  -0.02          0.31
# 12         183240000.0               N/A  -2.15          4.72
# 13       50840000000.0             27.12   2.33          5.32
# 14          17750000.0               N/A    N/A          0.36
# 15          18970000.0               N/A    N/A          0.73
# 16          41690000.0               N/A    N/A           N/A
# 17          45020000.0               N/A    N/A          0.83
# 18        2630000000.0             21.88   3.02          2.01
# 19          13360000.0               N/A    N/A          1.39
#
#                 Dividend Payout Ratio        Value Metric
# 0                    N/A          0.0                 N/A
# 1                    N/A          0.0                 N/A
# 2   0.030699999999999998          1.6   32.25623362763171
# 3                    N/A          0.0                 N/A
# 4                    N/A          0.0                 N/A
# 5                    N/A          0.0                 N/A
# 6                    N/A          0.0                 N/A
# 7                    N/A          0.0                 N/A
# 8                 0.0472          N/A                 N/A
# 9    0.16670000000000001          N/A                 N/A
# 10                0.0504       0.0753  2.5000000000000004
# 11                   N/A          0.0                 N/A
# 12                   N/A          0.0                 N/A
# 13                 0.019          0.4  141.58822374877332
# 14                   N/A          0.0                 N/A
# 15                   N/A          0.0                 N/A
# 16                   N/A          0.0                 N/A
# 17                   N/A          0.0                 N/A
# 18                   N/A          0.0   43.97879999999999
# 19                   N/A          0.0                 N/A

# %%
# This block can be used to revert to yesterday

#symbol_list = open_list()
#for symbol in symbol_list:
#    f = open('Data/' + symbol +'-TO.csv', "r+")
#    lines = f.readlines()
#    lines.pop()
#    f = open('Data/' + symbol +'-TO.csv', "w+")
#    f.writelines(lines)
