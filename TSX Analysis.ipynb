# %%
import re
import csv
import os
import datetime
import time
import pandas as pd

# %%
tsx_df = pd.read_csv('tsx.csv')
tsx_df.sort_values(by=['Value Metric'], inplace = True)
tsx_df.head(50)
# Out:
#                                           Company Name  Symbol  Year  Month  \
# 246                             Haivision Systems Inc.     HAI  2021      3
# 520                                     TVA Group Inc.   TVA-B  2021      3
# 33                              AGF Management Limited   AGF-B  2021      3
# 97   Morguard North American Residential Real Estat...  MRG-UN  2021      3
# 10                    Precious Metals and Mining Trust  MMP-UN  2021      3
# 518                 Sentry Select Primary Metals Corp.     PME  2021      3
# 68                         Cipher Pharmaceuticals Inc.     CPH  2021      3
# 21               Hammond Manufacturing Company Limited   HMM-A  2021      3
# 11                  Sherritt International Corporation       S  2021      3
# 662              Inovalis Real Estate Investment Trust  INO-UN  2021      3
# 682       Minto Apartment Real Estate Investment Trust   MI-UN  2021      3
# ...

# %%
tech = tsx_df[tsx_df['Sector'] == 'Technology']
tech.sort_values(by = ['Value Metric'], inplace = True)
tech.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                           Company Name Symbol  Year  Month  Day  \
# 333                   Quarterhill Inc.   QTRH  2021      3    4
# 230                     Celestica Inc.    CLS  2021      3    4
# 339  Intermap Technologies Corporation    IMP  2021      3    4
# 569            Maxar Technologies Inc.   MAXR  2021      3    4
# 380                           CGI Inc.  GIB-A  2021      3    4
# 366        Evertz Technologies Limited     ET  2021      3    4
# 176                Photon Control Inc.    PHO  2021      3    4
# 396           Enghouse Systems Limited   ENGH  2021      3    4
# 364                  Real Matters Inc.   REAL  2021      3    4
# ...

# %%
energy = tsx_df[tsx_df['Sector'] == 'Energy']
energy.sort_values(by = ['Value Metric'], inplace = True)
energy.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                Company Name Symbol  Year  Month  Day  \
# 249                 Yangarra Resources Ltd.    YGR  2021      3    4
# 758                           Enerflex Ltd.    EFX  2021      3    4
# 464                       Mega Uranium Ltd.    MGA  2021      3    4
# 628                   Condor Petroleum Inc.    CPI  2021      3    3
# 22                            CNOOC Limited    CNU  2021      3    4
# 567       Uranium Participation Corporation      U  2021      3    4
# 394  North American Construction Group Ltd.    NOA  2021      3    4
# 814                   TC Energy Corporation    TRP  2021      3    4
# ...

# %%
materials = tsx_df[tsx_df['Sector'] == 'Basic Materials']
materials.sort_values(by = ['Value Metric'], inplace = True)
materials.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                            Company Name Symbol  Year  Month  Day  \
# 518  Sentry Select Primary Metals Corp.    PME  2021      3    4
# 11   Sherritt International Corporation      S  2021      3    4
# 378   Starcore International Mines Ltd.    SAM  2021      3    4
# 800       Turquoise Hill Resources Ltd.    TRQ  2021      3    4
# 869                     Goodfellow Inc.    GDL  2021      3    4
# 804        Sulliden Mining Capital Inc.    SMC  2021      3    4
# 846                 Trilogy Metals Inc.    TMQ  2021      3    4
# 562               Orvana Minerals Corp.    ORV  2021      3    4
# ...

# %%
healthcare = tsx_df[tsx_df['Sector'] == 'Healthcare']
healthcare.sort_values(by = ['Value Metric'], inplace = True)
healthcare.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Company Name Symbol  Year  Month  Day  Closing Price  \
# 68      Cipher Pharmaceuticals Inc.    CPH  2021      3    4          0.870
# 29   Medical Facilities Corporation     DR  2021      3    4          7.100
# 43         Knight Therapeutics Inc.    GUD  2021      3    4          5.050
# 101                Extendicare Inc.    EXE  2021      3    4          6.820
# 477      Crescita Therapeutics Inc.    CTX  2021      3    4          0.860
# 108          Viemed Healthcare Inc.    VMD  2021      3    4         12.340
# 119  Andlauer Healthcare Group Inc.    AND  2021      3    4         36.480
# ...

# %%
consumer = tsx_df[tsx_df['Sector'] == 'Consumer Cyclical']
consumer.sort_values(by = ['Value Metric'], inplace = True)
consumer.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                            Company Name  Symbol  Year  Month  Day  \
# 31                        Supremex Inc.     SXP  2021      3    4
# 568        Taiga Building Products Ltd.     TBL  2021      3    4
# 125           Pizza Pizza Royalty Corp.     PZA  2021      3    4
# 235                     BMTC Group Inc.     GBT  2021      3    4
# 754       The Keg Royalties Income Fund  KEG-UN  2021      3    4
# 376            Leon's Furniture Limited     LNF  2021      3    4
# 577           Exco Technologies Limited     XTC  2021      3    4
# 434                 Linamar Corporation     LNR  2021      3    4
# ...

# %%
utilities = tsx_df[tsx_df['Sector'] == 'Utilities']
utilities.sort_values(by = ['Value Metric'], inplace = True)
utilities.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 Company Name  Symbol  Year  Month  Day  \
# 429                             AltaGas Ltd.     ALA  2021      3    4
# 545                        Hydro One Limited       H  2021      3    4
# 258                                ATCO Ltd.   ACO-X  2021      3    4
# 630                                ATCO Ltd.   ACO-Y  2021      3    4
# 324                       Emera Incorporated     EMA  2021      3    4
# 761              Polaris Infrastructure Inc.     PIF  2021      3    4
# 596                              Fortis Inc.     FTS  2021      3    4
# 56                        Etrion Corporation     ETX  2021      3    4
# ...

# %%
finance = tsx_df[tsx_df['Sector'] == 'Financial Services']
finance.sort_values(by = ['Value Metric'], inplace = True)
finance.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                           Company Name  Symbol  Year  Month  \
# 33                              AGF Management Limited   AGF-B  2021      3
# 10                    Precious Metals and Mining Trust  MMP-UN  2021      3
# 288                        United Corporations Limited     UNC  2021      3
# 638  Trez Capital Senior Mortgage Investment Corpor...     TZS  2021      3
# 656                        Aberdeen International Inc.     AAB  2021      3
# 604                  E-L Financial Corporation Limited     ELF  2021      3
# 334                             Big Pharma Split Corp.     PRM  2021      3
# ...

# %%
industrials = tsx_df[tsx_df['Sector'] == 'Industrials']
industrials.sort_values(by = ['Value Metric'], inplace = True)
industrials.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                    Company Name Symbol  Year  Month  Day  \
# 246                      Haivision Systems Inc.    HAI  2021      3    4
# 21        Hammond Manufacturing Company Limited  HMM-A  2021      3    4
# 286                         Dexterra Group Inc.    DXT  2021      3    4
# 100                              ADF Group Inc.    DRX  2021      3    4
# 295                Hammond Power Solutions Inc.  HPS-A  2021      3    4
# 756              Magellan Aerospace Corporation    MAL  2021      3    4
# 647                       Transcontinental Inc.  TCL-A  2021      3    4
# ...

# %%
consumer_defensive = tsx_df[tsx_df['Sector'] == 'Consumer Defensive']
consumer_defensive.sort_values(by = ['Value Metric'], inplace = True)
consumer_defensive.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               Company Name Symbol  Year  Month  Day  \
# 67   Swiss Water Decaffeinated Coffee Inc.    SWP  2021      3    4
# 412               Lassonde Industries Inc.  LAS-A  2021      3    4
# 113                  Andrew Peller Limited  ADW-A  2021      3    4
# 755          High Liner Foods Incorporated    HLF  2021      3    4
# 482                Apollo Healthcare Corp.    AHC  2021      3    4
# 463                  Andrew Peller Limited  ADW-B  2021      3    4
# 537                  George Weston Limited     WN  2021      3    4
# 530                      Rogers Sugar Inc.    RSI  2021      3    4
# ...

# %%
communication = tsx_df[tsx_df['Sector'] == 'Communication Services']
communication.sort_values(by = ['Value Metric'], inplace = True)
communication.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                             Company Name Symbol  Year  Month  Day  \
# 520                       TVA Group Inc.  TVA-B  2021      3    4
# 163                          Cogeco Inc.    CGO  2021      3    4
# 392           Cogeco Communications Inc.    CCA  2021      3    4
# 421             Shaw Communications Inc.  SJR-B  2021      3    4
# 607                  Stingray Group Inc.  RAY-B  2021      3    4
# 503                  Stingray Group Inc.  RAY-A  2021      3    4
# 631           Rogers Communications Inc.  RCI-B  2021      3    4
# 571                             BCE Inc.    BCE  2021      3    4
# ...

# %%
gaming = tsx_df[tsx_df['Industry'] == 'Electronic Gaming & Multimedia']
gaming.sort_values(by = ['Value Metric'], inplace = True)
gaming.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                         Company Name Symbol  Year  Month  Day  Closing Price  \
# 73   Enthusiast Gaming Holdings Inc.   EGLX  2021      3    4           7.30
# 705      Score Media and Gaming Inc.    SCR  2021      3    4          29.23
#
#                      Sector                        Industry    Market Cap  \
# 73   Communication Services  Electronic Gaming & Multimedia  8.443700e+08
# 705  Communication Services  Electronic Gaming & Multimedia  1.470000e+09
#
#      Price to Earnings   PEG  Price to Book  Dividend  Payout Ratio  \
# 73                 NaN   NaN           5.09       NaN           0.0
# ...

# %%
banks = tsx_df[tsx_df['Symbol'].isin(['CM', 'RY', 'TD', 'BMO', 'BNS'])]
banks.sort_values(by = ['Value Metric'], inplace = True)
banks.head(20)
# Out:
# c:\users\c_the\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                            Company Name Symbol  Year  Month  Day  \
# 340                    Bank of Montreal    BMO  2021      3    4
# 102  Canadian Imperial Bank of Commerce     CM  2021      3    4
# 636           The Toronto-Dominion Bank     TD  2021      3    4
# 822             The Bank of Nova Scotia    BNS  2021      3    4
# 877                Royal Bank of Canada     RY  2021      3    4
#
#      Closing Price              Sector           Industry    Market Cap  \
# 340         106.55  Financial Services  Banks—Diversified  6.892000e+10
# 102         121.22  Financial Services  Banks—Diversified  5.429000e+10
# ...
